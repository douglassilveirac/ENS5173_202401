# %% [markdown]
# # Numpy arrays

# %%
import numpy as np

# Criando um vetor de dados aleatórios
data = np.random.rand(1000,2)

# Verificando o tamanho do vetor
print(data.shape)
print(np.size(data))

# Print de uma amostra dos dados
print(data[0:10])
print(data[0:10].shape)
# Out:
# (1000, 2)
# 2000
# [[0.98849483 0.73478771]
#  [0.65678019 0.74525137]
#  [0.36342947 0.94056711]
#  [0.97457339 0.30245585]
#  [0.18164075 0.33414793]
#  [0.65463873 0.31156398]
#  [0.39086524 0.12710589]
#  [0.20624774 0.43017889]
#  [0.5875451  0.76263   ]
#  [0.45751866 0.56395567]]
# (10, 2)

# %%
# cria um vetor de dados aleatórios de ordem 1000x2, verifica o seu tamanho e imprime uma amostra dos primeiros 10x2 elementos

# %%
# Usando Monte-Carlo
dataMax = 1000
dataMin = 10
data = (dataMax - dataMin)*data + dataMin
print(data[0:10])
# Out:
# [[988.60987841 737.43982983]
#  [660.21238477 747.79885989]
#  [369.7951718  941.16143762]
#  [974.82765491 309.43129493]
#  [189.82433924 340.80645222]
#  [658.09233939 318.44834339]
#  [396.95658532 135.83483042]
#  [214.18526265 435.87709632]
#  [591.66964574 765.00370303]
#  [462.9434697  568.31611028]]

# %%
# técnica de Monte-Carlo para definir o valor máximo e mínimo que o elemento pode assumir

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3)
ax[0].plot(data)
ax[1].plot(data[:,0])
ax[2].plot(data[:,1])
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
# cria 3 gráficos onde cada um deles acessa uma coluna diferente de dados da matriz data

# %%
# Criando um dado 2D 
data3d = np.sin(np.random.rand(1000,1000))
print(data3d)
# Out:
# [[0.0388419  0.41169252 0.38521686 ... 0.74629896 0.57886515 0.52032612]
#  [0.56004139 0.76207202 0.61425322 ... 0.12233054 0.23298678 0.61660376]
#  [0.50923739 0.37960881 0.70049991 ... 0.55801917 0.63060097 0.82574439]
#  ...
#  [0.29522992 0.07395806 0.20296937 ... 0.82065083 0.8157338  0.71108981]
#  [0.41419183 0.57900062 0.09113138 ... 0.09927442 0.65154962 0.48077324]
#  [0.05135925 0.74287662 0.33772389 ... 0.78965926 0.67523902 0.46839473]]

# %%
# cria um array onde os valores são os senos de números aleatórios e em seguida mostra os primeiros e últimos elementos da matriz 1000x1000

# %%
# Plotando um dado 3D
fig2, ax2 = plt.subplots()
ax2.pcolor(data3d)

# %%
# utiliza o matplotlib para gerar figuras a partir de um eixo

# %%
# Criando vertor temporal
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1, "h"))
print(dtime[1:10])
print(dtime.shape)
print(type(dtime))
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %%
# cria uma sequência de datas e horários em um intervalo de 1 hora durante 1 ano

# %% [markdown]
# # PANDAS

# %%
import pandas as pd

# Criando um dataframe
df = pd.DataFrame()

# %%
# importa a biblioteca panda e cria um dataframe vazio

# %%
# Monstrando um dataframe
df['datetime'] = dtime

# %%
# inclui uma coluna ao dataframe

# %%
# Criando uma coluna random dentro do dataframe df
df['random'] = np.random.rand(df.shape[0])

# %%
df['random'][1:10]
# Out:
# 1    0.801970
# 2    0.454881
# 3    0.721181
# 4    0.636054
# 5    0.141720
# 6    0.085919
# 7    0.169723
# 8    0.231103
# 9    0.972606
# Name: random, dtype: float64

# %%
# acessa os valores da segunda a décima coluna

# %%
# Indexação
df.iloc[:,0]
# Out:
# 0      2022-01-01 00:00:00
# 1      2022-01-01 01:00:00
# 2      2022-01-01 02:00:00
# 3      2022-01-01 03:00:00
# 4      2022-01-01 04:00:00
#                ...
# 8755   2022-12-31 19:00:00
# 8756   2022-12-31 20:00:00
# 8757   2022-12-31 21:00:00
# 8758   2022-12-31 22:00:00
# 8759   2022-12-31 23:00:00
# Name: datetime, Length: 8760, dtype: datetime64[s]

# %%
# acessa todos os valores de todas as linhas da primeira coluna

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime'])
df
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.948737
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.801970
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.454881
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.721181
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.636054
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.268344
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.807545
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.205508
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.028941
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.860094
#
# [8760 rows x 2 columns]

# %%
# redefine o índice do dataframe para a coluna datetime

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day

# %%
# adiciona novas colunas ao dataframe

# %%
tt = np.arange(0,df.shape[0],1)
print(tt.shape)
df['sazonal'] = (np.cos(tt/(360*4)))
df['timeSeries'] = 10*df['sazonal']+df['random']
#df['sazonal'].plot()
df['timeSeries'].plot(color='red')
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
# cria novas colunas através de combinação linear e plota um gráfico de linha vermelha em seguida

# %%
df
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.948737  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.801970  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.454881  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.721181  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.636054  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.268344  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.807545  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.205508  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.028941  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.860094  2022     12   31  0.979958
#
#                      timeSeries
# datetime
# 2022-01-01 00:00:00   10.948737
# 2022-01-01 01:00:00   10.801967
# 2022-01-01 02:00:00   10.454872
# 2022-01-01 03:00:00   10.721159
# 2022-01-01 04:00:00   10.636016
# ...                         ...
# 2022-12-31 19:00:00   10.062352
# 2022-12-31 20:00:00   10.602952
# 2022-12-31 21:00:00   10.002310
# 2022-12-31 22:00:00    9.827134
# 2022-12-31 23:00:00   10.659673
#
# [8760 rows x 7 columns]

# %%
# acessa o novo dataframe

# %%
# Salvar meu dataframe

df.to_csv(r'C:\Users\dodo_\Documents\GitHub\ENS5173_202401\dados\brutos\noise_2022.csv')

# %%
# salva o dataframe criado em um arquivo csv na pasta do computador

# %%
# Criando uma função
def noiseCreation(path, year):
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas

    Criado por Leonardo
    """
    
    # Criando um dataframe
    df = pd.DataFrame()
    
    # Criando vertor temporal
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h"))
    
    # Monstrando um dataframe
    df['datetime'] = dtime
        
    # Datetime como index do dataframe
    df = df.set_index(df['datetime'])
    
    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day
    
    # Crio uma coluna random
    df['random'] = np.random.rand(df.shape[0])
    
    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = (np.cos(tt/(360*4)))
    df['timeSeries'] = 10*df['sazonal']+df['random']
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red')
    df.to_csv(path+'/noise_'+str(year)+'.csv')
    
    return df

# %%
path = 'C:/Users/dodo_/Documents/GitHub/ENS5173_202401/dados/brutos'
df2 = noiseCreation(path,2050)
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010):
    print(ii)
    df = noiseCreation(path,ii)
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %%
df
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.519300  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.585545  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.554783  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.265507  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.856287  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.028407  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.506054  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.653893  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.572806  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.481224  0.979958
#
#                      timeSeries
# datetime
# 2009-01-01 00:00:00   10.519300
# 2009-01-01 01:00:00   10.585542
# 2009-01-01 02:00:00   10.554773
# 2009-01-01 03:00:00   10.265485
# 2009-01-01 04:00:00   10.856249
# ...                         ...
# 2009-12-31 19:00:00    9.822415
# 2009-12-31 20:00:00   10.301461
# 2009-12-31 21:00:00   10.450696
# 2009-12-31 22:00:00   10.370999
# 2009-12-31 23:00:00   10.280803
#
# [8760 rows x 7 columns]

# %%
anos = [2001,2030,2032,2053,2060]

for ano in anos:
    print(ano)
    if ano > 2030:
        df = noiseCreation(path,ano)
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %%
import os
files = os.listdir(path)
print(files)

allData = []
for file in files:
    if file.endswith('.csv'):
        print(file)
        data = pd.read_csv(path+'/'+file)
        allData.append(data)
# Out:
# ['noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2022.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv']
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2022.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %%
allDataDf = pd.concat(allData)

# %%
allDataDf
# Out:
#                  datetime           datetime.1  year  month  day    random  \
# 0     2002-01-01 00:00:00  2002-01-01 00:00:00  2002      1    1  0.278362
# 1     2002-01-01 01:00:00  2002-01-01 01:00:00  2002      1    1  0.543901
# 2     2002-01-01 02:00:00  2002-01-01 02:00:00  2002      1    1  0.603659
# 3     2002-01-01 03:00:00  2002-01-01 03:00:00  2002      1    1  0.297254
# 4     2002-01-01 04:00:00  2002-01-01 04:00:00  2002      1    1  0.878476
# ...                   ...                  ...   ...    ...  ...       ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  2060     12   31  0.419059
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  2060     12   31  0.510616
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  2060     12   31  0.731527
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  2060     12   31  0.814986
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  2060     12   31  0.009582
#
#        sazonal  timeSeries
# 0     1.000000   10.278362
# 1     1.000000   10.543899
# 2     0.999999   10.603650
# 3     0.999998   10.297232
# 4     0.999996   10.878437
# ...        ...         ...
# 8779  0.982630   10.245359
# 8780  0.982759   10.338202
# 8781  0.982887   10.560395
# 8782  0.983014   10.645131
# 8783  0.983142    9.840999
#
# [113976 rows x 8 columns]

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries'])
